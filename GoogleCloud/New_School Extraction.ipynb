# %%
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/Users/rodrigopimenta/Desktop/GoogleCloud/NLP_Project.json"

# %%
#Test

# Imports the Google Cloud client library
from google.cloud import language
from google.cloud.language import enums
from google.cloud.language import types

# Instantiates a client
client = language.LanguageServiceClient()

# The text to analyze
text = u'Hello, world!'
document = types.Document(
    content=text,
    type=enums.Document.Type.PLAIN_TEXT)

# Detects the sentiment of the text
sentiment = client.analyze_sentiment(document=document).document_sentiment

print('Text: {}'.format(text))
print('Sentiment: {}, {}'.format(sentiment.score, sentiment.magnitude))
# Out:
# Text: Hello, world!
# Sentiment: 0.30000001192092896, 0.30000001192092896

# %%
#define entity recognition function

def entities_text(text):
    """Detects entities in the text."""
    client = language.LanguageServiceClient()

    # Instantiates a plain text document.
    document = types.Document(
        content=text,
        type=enums.Document.Type.PLAIN_TEXT)

    # Detects entities in the document. You can also analyze HTML with:
    #   document.type == enums.Document.Type.HTML
    entities = client.analyze_entities(document).entities

    # entity types from enums.Entity.Type
    entity_type = ('UNKNOWN', 'PERSON', 'LOCATION', 'ORGANIZATION',
                  'EVENT', 'WORK_OF_ART', 'CONSUMER_GOOD', 'OTHER')
   
    string = []
    for entity in entities:
        #string.append('=' * 20)
        string.append('{}: {}'.format(entity.name,entity_type[entity.type]))
        #string.append(u'{:<16}: {}'.format('type', entity_type[entity.type]))
        #print('=' * 20)
        #print(u'{:<16}: {}'.format('name', entity.name))
        #print(u'{:<16}: {}'.format('type', entity_type[entity.type])) 
    return string
    print(string)

# %%
#input a resume string

temp = open('DIANE_ZAGHAL_resume.txt').read()
type (temp)
# Out:
# str

# %%
entities_text(temp)
# Out:
# ['PeopleSoft: ORGANIZATION',
#  'Life Cycle testing: OTHER',
#  'testing: OTHER',
#  'MD: LOCATION',
#  'software products: CONSUMER_GOOD',
#  'QUALIFICATIONS: OTHER',
#  'Test Engineer: PERSON',
#  'test engineer: PERSON',
#  'Integration: OTHER',
#  'modules: OTHER',
#  'experience: OTHER',
#  'Payroll: OTHER',
#  'experience: OTHER',
#  'DIANE ZAGHAL: PERSON',
#  'Worth Avenue Silver Spring: EVENT',
#  'Software Quality Assurance: OTHER',
#  'areas: LOCATION',
#  'System Regression: OTHER',
#  'Certification: OTHER',
#  'ITIL Certification: OTHER',
#  'Strengths: OTHER',
#  'delivery: OTHER',
#  'SUMMARY: OTHER',
#  'knowledge: OTHER',
#  'SUMMARY: OTHER',
#  'User Acceptance Testing: EVENT',
#  'Integration Testing: OTHER',
#  'System Testing: OTHER',
#  'Deployment: OTHER',
#  'configuration: OTHER',
#  'HRMS: OTHER',
#  'PeopleTools: OTHER',
#  'end users: PERSON',
#  'tester: OTHER',
#  'tester: PERSON',
#  'Excel: CONSUMER_GOOD',
#  'regression testing: EVENT',
# ...

# %%
listFromEntitiesFunction = entities_text(temp)

# %%
#type(x)
type(listFromEntitiesFunction[0])
# Out:
# str

# %%
parsedListSchools = []
for element in listFromEntitiesFunction:
    if ("ORGANIZATION") in element:
        if(("University" or "School" or "school" or "College") in element):
            parsedListSchools.append(element)
print(parsedList)
# Out:
# ['University of Maryland: ORGANIZATION']

# %%
#remove last 14 characters, removing ": ORGANIZATION"

finalListSchools = []
for element in parsedListSchools:
    if element.endswith(': ORGANIZATION'):
        element = element[:-14]
        finalListSchools.append(element)
print(finalListSchools)
# Out:
# ['University of Maryland']
