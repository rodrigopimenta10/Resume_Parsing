# %%
import pandas

df = pandas.read_excel('majors2.xlsx')

df.columns
major_file = df['Majors'].values
#major_file = flattened
major_lower = [item.lower() for item in major_file]
print (major_lower)

#resume_path = r"/Users/yiyangzhou/Desktop/Zeng_Leah_Resume.txt"
#resume_path = r"/Users/yiyangzhou/Desktop/Yiyang (Eric) Zhou Resume 2017 Fall.txt"
#resume_path = r"/Users/yiyangzhou/Desktop/Wang_YilinResume.txt"
resume_path = r"/Users/yiyangzhou/Desktop/Ryan Holder Resume.txt"
#resume_path = r"/Users/yiyangzhou/Desktop/Shashidhar Karnati.txt"
#resume_path = r"/Users/yiyangzhou/Desktop/all_text1.txt"
resume_file = open(resume_path).read()
resume_file = resume_file.lower()
# Out:
# ['mathematical biology', 'intelligence', 'crafts', 'craft design, folk art and artisanry', 'crafts craft design, folk art and artisanry', 'mason', 'masonry', 'mason masonry', 'environmental', 'environmental health engineering', 'environmental environmental health engineering', 'building', 'construction site management', 'manager', 'veterinary pathology and pathobiology', 'manufacturing engineering', 'meeting and event planning', 'astronomy', 'airline', 'commercial', 'professional pilot and flight crew', 'russian, central european, east european and eurasian studies', 'clinical nutrition', 'nutritionist', 'clinical nutritionist', 'geriatric nurse', 'nursing', 'geriatric nursing', 'human computer interaction', 'heavy equipment maintenance technology', 'technician', 'heavy equipment maintenance technician', 'clinical nurse leader', 'manufacturing engineering technology', 'technician', 'manufacturing engineering technician', 'econometrics and quantitative economics', 'cell physiology', 'veterinary sciences', 'veterinary clinical sciences', 'veterinary veterinary clinical sciences', 'political communication', 'prepress', 'desktop publishing and digital imaging design', 'prepress desktop publishing and digital imaging design', 'molecular genetics', 'sales, distribution, and marketing operations', 'legal administrative assistant', 'secretary', 'legal administrative secretary', 'advanced legal research', 'studies', 'advanced legal studies', 'information technology', 'parks, recreation and leisure studies', 'fiber, textile and weaving arts', 'forensic science and technology', 'business machine repair', 'agricultural and horticultural plant breeding', "women's studies", 'autobody', 'collision and repair technology', 'technician', 'analysis and functional analysis', 'agricultural and food products processing', 'herbalism', 'herbalist', 'herbalism herbalist', 'security system installation, repair, and inspection technology', 'technician', 'security system installation, repair, and inspection technician', 'intercultural', 'multicultural and diversity studies', 'intercultural multicultural and diversity studies', 'phlebotomy technician', 'phlebotomist', 'phlebotomy phlebotomist', 'business', 'commerce', 'business commerce', 'pathology', 'experimental pathology', 'pathology experimental pathology', 'jewish', 'judaic studies', 'jewish judaic studies', 'communications technology', 'technician', 'communications technician', 'ophthalmic laboratory technology', 'technician', 'ophthalmic laboratory technician', 'plastics and polymer engineering technology', 'technician', 'plastics and polymer engineering technician', 'permanent cosmetics', 'makeup and tattooing', 'permanent makeup and tattooing', 'meat cutting', 'meat cutter', 'meat meat cutter', 'medical radiologic technology', 'science - radiation therapist', 'medical radiologic science - radiation therapist', 'web page, digital', 'multimedia and information resources design', 'web page, multimedia and information resources design', 'african studies', 'bartending', 'bartender', 'bartending bartender', 'communication sciences and disorders', 'environmental science', 'respiratory care therapy', 'therapist', 'respiratory care therapist', 'hotel, motel, and restaurant management', 'algebra and number theory', 'writing', 'polish studies', 'locksmithing and safe repair', 'foreign languages and literatures', 'communications systems installation and repair technology', 'animation, interactive technology, video graphics and special effects', 'environmental biology', 'insurance', 'small business administration', 'management', 'small business management', 'atmospheric sciences and meteorology', 'classical, ancient mediterranean and near eastern studies and archaeology', 'english language and literature', 'family and consumer sciences', 'human sciences communication', 'family and consumer human sciences communication', 'dental laboratory technology', 'technician', 'dental laboratory technician', 'water, wet ...

# %%
import nltk
import re
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import WordPunctTokenizer
from nltk.collocations import BigramCollocationFinder
from nltk.metrics import BigramAssocMeasures
from nltk.tokenize import RegexpTokenizer
from nltk import ngrams

tokenizer = RegexpTokenizer(r'\w+')
resume_token = tokenizer.tokenize(resume_file) 

def get_bigrams(input):
    n = 2
    result = []
    bigrams = ngrams(input, n)
    for grams in bigrams:
        x = "%s %s" % grams
        result.append(x)
    return (result)    
    print (result)


test1 = get_bigrams(resume_token)
#print (test1)

def get_threegrams(input):
    n = 3
    result = []
    threegrams = ngrams(input, n)
    for grams in threegrams:
        x = "%s %s %s" % grams
        result.append(x)
    return (result)    
    print (result)

test2 = get_threegrams(resume_token)
#print (test2)

def extract_majors(a,b):
    majors=[]
    for x in a:
        if x in b:
            majors.append(x)
    return (majors)
    print (majors)
    

unigram_major = extract_majors(resume_token, major_lower)  
bigram_major = extract_majors(get_bigrams(resume_token), major_lower)
threegram_major = extract_majors(get_threegrams(resume_token), major_lower)


#print (unigram_major)
#print (bigram_major)
#print (threegram_major)


combined_majors_list = unigram_major + bigram_major + threegram_major

major_distinct = []
for i in combined_majors_list:
    if i not in major_distinct:
        major_distinct.append(i)
        
#print (combined_majors_list)
print (major_distinct)
# Out:
# ['education', 'economics', 'management', 'development', 'manager', 'technology', 'technician', 'computer', 'building', 'engineering', 'baker', 'business', 'marketing', 'fitness']

# %%
dict = {'Name': 5}
for i, element in enumerate(major_distinct):
   x = resume_file.find(element)
   dict[element] = x
   

del dict['Name']
print(dict)
# Out:
# {'technician': 870, 'fitness': 3771, 'business': 2478, 'technology': 789, 'management': 454, 'baker': 1999, 'manager': 735, 'building': 1548, 'marketing': 3326, 'computer': 957, 'economics': 215, 'development': 723, 'education': 113, 'engineering': 1656}

# %%
import re
import string

regular_expression = re.compile(r"/BA|BS|Bachelor of Science|Bachelor of Arts|BBA |B/A|Bachelor of Business Administration/", re.IGNORECASE)
bach_major_result = re.search(regular_expression, resume_file)
if bach_major_result:
   bach_major_result = bach_major_result.group()
print (bach_major_result)

if bach_major_result is not None:
    bach_major_index = resume_file.find(bach_major_result)
    print(bach_major_index)
# Out:
# bachelor of arts
# 195

# %%
import re
import string

regular_expression_two = re.compile(r"minor|Minor", re.IGNORECASE)
minor_result = re.search(regular_expression_two, resume_file)
if minor_result:
   minor_result = minor_result.group()
print (minor_result)

if minor_result is not None:
    minor_index = resume_file.find(minor_result)
    print(minor_index)
# Out:
# None

# %%
import re
import string

regular_expression_three = re.compile(r"Master|master", re.IGNORECASE)
master_major_result = re.search(regular_expression_three, resume_file)
if master_major_result:
   master_major_result = master_major_result.group()
print (master_major_result)


if master_major_result is not None:
    master_major_index = resume_file.find(master_major_result)
    print(master_major_index)
# Out:
# None

# %%
import re
import string

regular_expression_four = re.compile(r"university", re.IGNORECASE)
university_major_result = re.search(regular_expression_four, resume_file)
if university_major_result:
   university_major_result = university_major_result.group()
print (university_major_result)

if university_major_result is not None:
    university_major_index = resume_file.find(university_major_result)
    print(university_major_index)
# Out:
# university
# 123

# %%
#If a bachelors and masters are found. We want to distinguish them from each other.
if (bach_major_index != None)&&(minor_index == None)&&(master_major_index != None):
    len_until_master = abs((bach_major_index - master_major_index))
    
    updated_majors = []
    indexes_majors = []
    updated_masters = []
    indexes_masters = []
    
    
    if (bach_major_index < master_major_index):
        #Get bachelors
        upper_bound = bach_major_index+len_until_master
        lower_bound = bach_major_index
        for k, v in dict.items():
           if (lower_bound < v < upper_bound):
               updated_majors.append(k)
               indexes_majors.append(v)
        print(updated_majors)
        print(indexes_majors)

        #Get masters
        upper_bound = master_major_index+50
        lower_bound = master_major_index
        for k, v in dict.items():
           if (lower_bound < v < upper_bound):
               updated_masters.append(k)
               indexes_masters.append(v)
        print(updated_masters)
        print(indexes_masters)


    else:
    #if (master_major_index < bach_major_index)
        #Get bachelors
        upper_bound = bach_major_index+50
        lower_bound = bach_major_index
        for k, v in dict.items():
           if (lower_bound < v < upper_bound):
               updated_majors.append(k)
               indexes_majors.append(v)
        print(updated_majors)
        print(indexes_majors)

        #Get masters
        upper_bound = master_major_index+len_until_master
        lower_bound = master_major_index
        for k, v in dict.items():
           if (lower_bound < v < upper_bound):
               updated_masters.append(k)
               indexes_masters.append(v)
        print(updated_masters)
        print(indexes_masters)
# Out:
# ['economics']
# [215]

# %%
#If a bachelors and minor(s) are found. We want to distinguish them from each other.
if (bach_major_index != None)&&(minor_index != None)&&(master_major_index == None):
    len_until_minor = abs((bach_major_index - minor_index))
    
    updated_majors = []
    indexes_majors = []
    updated_minors = []
    indexes_minors = []
    
    if (bach_major_index < minor_index):
            #Get bachelors
            upper_bound = bach_major_index+len_until_minor
            lower_bound = bach_major_index
            for k, v in dict.items():
               if (lower_bound < v < upper_bound):
                   updated_majors.append(k)
                   indexes_majors.append(v)
            print(updated_majors)
            print(indexes_majors)
            
            #Get minor
            upper_bound = minor_index+50
            lower_bound = minor_index
            for k, v in dict.items():
               if (lower_bound < v < upper_bound):
                   updated_minors.append(k)
                   indexes_masters.append(v)
            print(updated_minors)
            print(indexes_minors)
            
            
        else:
        #if (minor_index < bach_major_index)
            #Get bachelors
            upper_bound = bach_major_index+50
            lower_bound = bach_major_index
            for k, v in dict.items():
               if (lower_bound < v < upper_bound):
                   updated_majors.append(k)
                   indexes_majors.append(v)
            print(updated_majors)
            print(indexes_majors)
            
            #Get minor
            upper_bound = minor_index+len_until_minor
            lower_bound = minor_index
            for k, v in dict.items():
               if (lower_bound < v < upper_bound):
                   updated_minors.append(k)
                   indexes_masters.append(v)
            print(updated_minors)
            print(indexes_minors)

# %%
if (len_until_master < len_until_minor):
    
if (len_until_minor < len_until_master):

# %%
#universities_list -> List of all extracted universities
#majors_minors_final_list -> List of all majors, masters, and minors

universities_dict_indexes = {'Name': 5}
for i, element in enumerate(universities_list):
   x = resume_file.find(element)
   universities_dict_indexes[element] = x
   

del universities_dict_indexes['Name']
print(universities_dict_indexes)

# %%
len_until_next = (first_index - second_index)
    
    first_majors = []
    first_indexes_majors = []
    second_majors = []
    second_indexes_masters = []
    
    
    if (bach_major_index < master_major_index):
        #Get bachelors
        upper_bound = bach_major_index+len_until_master
        lower_bound = bach_major_index
        for k, v in dict.items():
           if (lower_bound < v < upper_bound):
               updated_majors.append(k)
               indexes_majors.append(v)
        print(updated_majors)
        print(indexes_majors)

        #Get masters
        upper_bound = master_major_index+50
        lower_bound = master_major_index
        for k, v in dict.items():
           if (lower_bound < v < upper_bound):
               updated_masters.append(k)
               indexes_masters.append(v)
        print(updated_masters)
        print(indexes_masters)

# %%
upper_bound = master_major_index+100

updated_majors = []
indexes_majors = []
for k, v in dict.items():
   if (master_major_index < v < upper_bound):
       updated_majors.append(k)
       indexes_majors.append(v)

print(updated_majors)
print(indexes_majors)
# Out:
# ['economics']
# [215]

# %%
upper_bound = university_major_index+100

updated_majors = []
indexes_majors = []
for k, v in dict.items():
   if (university_major_index < v < upper_bound):
       updated_majors.append(k)
       indexes_majors.append(v)

print(updated_majors)
print(indexes_majors)
# Out:
# ['economics']
# [215]
