# %%
import pandas

df1 = pandas.read_excel('China_University.xlsx')
df2 = pandas.read_excel('India_University.xlsx')
df3 = pandas.read_excel('US_University.xlsx')
#df3 = open('List of US Universities.txt', 'r').readlines()

df1.columns
df2.columns
df3.columns
university_file1 = df1['Universities'].values
university_file2 = df2['Universities'].values
university_file3 = df2['Universities'].values

university_lower1 = [item.lower() for item in university_file1]
university_lower2 = [item.lower() for item in university_file2]
university_lower3 = [item.lower() for item in university_file3]
#university_lower3 = [item.lower() for item in df3]
university_combined = university_lower1 + university_lower2 + university_lower3

print (university_combined)

resume_path = r"/Users/rodrigopimenta/Desktop/Eric Extract/test resume/Zeng_Leah_Resume.txt"
#resume_path = r"/Users/yiyangzhou/Desktop/Yiyang (Eric) Zhou Resume 2017 Fall.txt"
#resume_path = r"/Users/yiyangzhou/Desktop/Wang_YilinResume.txt"
#resume_path = r"/Users/yiyangzhou/Desktop/all_text1.txt"
resume_file = open(resume_path).read().lower()
# Out:
# ['ningbo university of technology', 'shanghai university of political science and law', 'zhengzhou chenggong university of finance and economics', 'east china university of technology', 'shenyang university', 'anshun university', 'neijiang normal university', 'heilongjiang university of finance and economics', 'beijing dance academy', 'wenzhou university', 'central south university of forestry and technology', 'qujing normal university', 'xinyang normal university', 'fujian medical university', 'heze university', 'jiangsu teachers university of technology', 'west anhui university', 'chengdu university of technology', 'tianjin foreign studies university', 'ningxia normal university', 'luoyang institute of science and technology', 'china youth university for political sciences', 'hubei university of medicine', 'beijing institute of technology', 'nanjing agricultural university', 'university of international relations', 'liaoning university of international business and economics', 'xinxiang university', 'dalian university of foreign languages', 'anyang institute of technology', "xi'an university of science and technology", 'chuzhou university', 'fuzhou university', 'guizhou university of engineering science', 'sichuan fine arts institute', 'jining normal university', 'hunan institute of information technology', 'shandong sport university', 'chongqing medical university', 'shijiazhuang university', 'baoji university of arts and sciences', 'shaanxi institute of international trade and commerce', 'guangdong medical university', 'henan normal university', 'anhui university of technology', 'liaoning university of traditional chinese medicine', 'huaihai institute of technology', 'qiqihar university', "xi'an peihua university", "xi'an academy of fine arts", 'suzhou university', 'hunan university of science and engineering', 'qinzhou university', 'wuhan textile university', 'zhejiang sci-tech university', 'anhui science and technology university', 'chongqing university of science and technology', 'northeast forestry university', 'jilin jianzhu university', 'kashi university', 'sichuan tourism university', 'yuxi normal university', 'wuhan university', 'yanbian university of science and technology', 'shangluo university', 'hunan institute of science and technology', 'guiyang university', 'zhejiang wanli university', 'ningxia medical university', 'beijing foreign studies university', 'shanxi university of traditional chinese medicine', 'northwest university for nationalities', 'dalian art college', 'shanghai university of electric power', 'tianjin university of traditional chinese medicine', 'changshu institute of technology', 'changzhi medical college', 'jiangnan university', 'hubei university of economics', 'civil aviation flight university of china', 'china university of geosciences wuhan', 'jianghan university', 'guangxi university', 'chengdu college of arts and sciences', 'tianjin university of science and technology', 'beijing university of chinese medicine', "xi'an university of posts and telecommunications", 'eastern liaoning university', "xi'an jiaotong-liverpool university", 'anhui normal university', 'central university of finance and economics', 'qingdao huanghai university', 'zhangjiakou university', 'xinjiang university', 'donghua university', 'lishui university', 'qiannan normal college for nationalities', 'henan institute of engineering', 'fuyang teachers college', 'tianjin university', 'jiangxi university of science and technology', 'shanxi normal university', 'xinxiang medical university', 'chengdu university of information technology', 'yanshan university', 'shanxi university', 'henan university of urban construction', 'north university of china', 'zaozhuang university', 'changsha medical university', 'china university of mining and technology', 'shenyang urban construction university', 'shanghai theatre academy', "hunan women's university", 'jiangsu university of science and technology', 'beijing university of posts and ...

# %%
import nltk
import re
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import WordPunctTokenizer
from nltk.collocations import BigramCollocationFinder
from nltk.metrics import BigramAssocMeasures
from nltk.tokenize import RegexpTokenizer
from nltk import ngrams

tokenizer = RegexpTokenizer(r'\w+')
resume_token = tokenizer.tokenize(resume_file) 

def get_bigrams(input):
    n = 2
    result = []
    bigrams = ngrams(input, n)
    for grams in bigrams:
        x = "%s %s" % grams
        result.append(x)
    return (result)    
    print (result)


test1 = get_bigrams(resume_token)
#print (test1)

def get_threegrams(input):
    n = 3
    result = []
    threegrams = ngrams(input, n)
    for grams in threegrams:
        x = "%s %s %s" % grams
        result.append(x)
    return (result)    
    print (result)

test2 = get_threegrams(resume_token)
#print (test2)

def get_fourgrams(input):
    n = 4
    result = []
    fourgrams = ngrams(input, n)
    for grams in fourgrams:
        x = "%s %s %s %s" % grams
        result.append(x)
    return (result)    
    print (result)

test3 = get_fourgrams(resume_token)
#print (test3)

def get_fivegrams(input):
    n = 5
    result = []
    fivegrams = ngrams(input, n)
    for grams in fivegrams:
        x = "%s %s %s %s %s" % grams
        result.append(x)
    return (result)    
    print (result)

test4 = get_fivegrams(resume_token)
#print (test4)

def get_sixgrams(input):
    n = 6
    result = []
    sixgrams = ngrams(input, n)
    for grams in sixgrams:
        x = "%s %s %s %s %s %s" % grams
        result.append(x)
    return (result)    
    print (result)

test5 = get_sixgrams(resume_token)
#print (test5)

def extract_university(a,b):
    university=[]
    for x in a:
        if x in b:
            university.append(x)
    return (university)
    print (university)
    

unigram_university = extract_university(resume_token, university_combined)  
bigram_university = extract_university(get_bigrams(resume_token), university_combined)
threegram_university = extract_university(get_threegrams(resume_token), university_combined)
fourgram_university = extract_university(get_fourgrams(resume_token), university_combined)
fivegram_university = extract_university(get_fivegrams(resume_token), university_combined)
sixgram_university = extract_university(get_sixgrams(resume_token), university_combined)

combined_university_extraction = bigram_university + threegram_university + fourgram_university + fivegram_university + sixgram_university

'''
university_distinct = []
for i in combined_university_extraction:
    if i not in university_distinct:
        university_distinct.append(i)

print (university_distinct)
'''
print (combined_university_extraction)
# Out:
# ['fudan university']

# %%
#test
print (bigram_university)
print (threegram_university)
print (fourgram_university)
print (fivegram_university)
print (sixgram_university)
print (len(combined_university_extraction))
# Out:
# ['fudan university']
# []
# []
# []
# []
# 1

# %%
universities_list = combined_university_extraction

# %%
import pandas

df = pandas.read_excel('majors2.xlsx')

df.columns
major_file = df['Majors'].values
#major_file = flattened
major_lower = [item.lower() for item in major_file]
print (major_lower)

#resume_path = r"/Users/yiyangzhou/Desktop/Zeng_Leah_Resume.txt"
#resume_path = r"/Users/yiyangzhou/Desktop/Yiyang (Eric) Zhou Resume 2017 Fall.txt"
#resume_path = r"/Users/yiyangzhou/Desktop/Wang_YilinResume.txt"
resume_path = r"/Users/rodrigopimenta/Desktop/Eric Extract/test resume/Zeng_Leah_Resume.txt"
#resume_path = r"/Users/yiyangzhou/Desktop/Shashidhar Karnati.txt"
#resume_path = r"/Users/yiyangzhou/Desktop/all_text1.txt"
resume_file = open(resume_path).read()
resume_file = resume_file.lower()
# Out:
# ['captive wildlife care and education( unity college in maine ) ', 'contemporary christian music ( greenville college)', 'individually structured major  ( university of colorado denver)', 'recording industry ( greenville college)', 'sustainable design and technology ( unity college in maine )', 'animal training', 'dog', 'pet', 'animal grooming', 'equestrian', 'equine studies', 'equestrian equine studies', 'taxidermy', 'taxidermist', 'taxidermy taxidermist', 'agricultural and food products processing', 'agribusiness', 'agricultural business operations', 'agribusiness agricultural business operations', 'agricultural business and management', 'agricultural business technology', 'agricultural economics', 'agricultural', 'farm supplies retailing and wholesaling', 'agricultural farm supplies retailing and wholesaling', 'farm', 'farm and ranch management', 'farm farm and ranch management', 'agricultural mechanics and equipment', 'machine technology', 'agricultural mechanics and machine technology', 'agricultural mechanization', 'agricultural power machinery operation', 'agricultural production operations', 'agroecology and sustainable agriculture', 'animal', 'livestock husbandry and production', 'animal livestock husbandry and production', 'aquaculture', 'crop production', 'dairy husbandry and production', 'horse husbandry', 'equine science and management', 'horse equine science and management', 'viticulture and enology', 'agricultural and extension education services', 'agricultural communication', 'journalism', 'agricultural journalism', 'agricultural animal breeding', 'animal health', 'animal nutrition', 'animal sciences', 'dairy science', 'livestock management', 'poultry science', 'applied horticulture', 'horticulture operations', 'applied horticulture operations', 'floriculture', 'floristry operations and management', 'floriculture floristry operations and management', 'greenhouse operations and management', 'landscaping and groundskeeping', 'ornamental horticulture', 'plant nursery operations and management', 'turf and turfgrass management', 'food science', 'food technology and processing', 'international agriculture', 'agricultural and horticultural plant breeding', 'agronomy and crop science', 'horticultural science', 'plant protection and integrated pest management', 'plant sciences', 'range science and management', 'soil chemistry and physics', 'soil microbiology', 'soil science and agronomy', 'architectural history and criticism', 'architectural and building sciences', 'technology', 'architectural and building technology', 'architectural technology', 'technician', 'architectural technician', 'architecture', 'city', 'urban, community and regional planning', 'city urban, community and regional planning', 'environmental design', 'architecture', 'environmental architecture', 'interior architecture', 'landscape architecture', 'real estate development', 'african studies', 'american', 'united states studies', 'civilization', 'asian studies', 'civilization', 'asian civilization', 'balkans studies', 'baltic studies', 'canadian studies', 'caribbean studies', 'chinese studies', 'commonwealth studies', 'east asian studies', 'european studies', 'civilization', 'european civilization', 'french studies', 'german studies', 'irish studies', 'italian studies', 'japanese studies', 'korean studies', 'latin american and caribbean studies', 'latin american studies', 'near and middle eastern studies', 'pacific area', 'pacific rim studies', 'pacific pacific rim studies', 'polish studies', 'regional studies (us, canadian, foreign)', 'russian studies', 'russian, central european, east european and eurasian studies', 'scandinavian studies', 'slavic studies', 'south asian studies', 'southeast asian studies', 'spanish and iberian studies', 'tibetan studies', 'ukraine studies', 'ural-altaic and central asian studies', 'western european studies', 'african-american', 'black studies', 'african-american black studies', 'american indian', 'native american s ...
